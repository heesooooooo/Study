# %%
import pandas as pd

# %%
pd.read_csv("20_24평균기온.txt", skiprows = 6)
# Out:
#                년월   지점  평균기온(℃)  평균최저기온(℃)  평균최고기온(℃)
# 0   \t\t\t2020-01  156      3.6        NaN        NaN
# 1   \t\t\t2020-02  156      2.4        NaN        NaN
# 2   \t\t\t2020-03  156      1.5        NaN        NaN
# 3   \t\t\t2020-04  156     -1.9        NaN        NaN
# 4   \t\t\t2020-05  156      0.1        NaN        NaN
# 5   \t\t\t2020-06  156      0.9        NaN        NaN
# 6   \t\t\t2020-07  156     -2.5        NaN        NaN
# 7   \t\t\t2020-08  156      1.1        NaN        NaN
# 8   \t\t\t2020-09  156     -0.9        NaN        NaN
# 9   \t\t\t2020-10  156     -0.4        NaN        NaN
# 10  \t\t\t2020-11  156      0.9        NaN        NaN
# 11  \t\t\t2020-12  156     -0.5        NaN        NaN
# 12  \t\t\t2021-01  156      0.4        NaN        NaN
# 13  \t\t\t2021-02  156      2.2        NaN        NaN
# 14  \t\t\t2021-03  156      3.1        NaN        NaN
# 15  \t\t\t2021-04  156      1.5        NaN        NaN
# ...

# %%
pd.read_csv("체감온도.txt", skiprows = 3)
# Out:
#              일자  기온(°C)  풍속(km/h)  체감온도(°C)
# 0    2020-01-01    -4.8      14.8     -10.3
# 1    2020-01-02     1.4       4.7       0.1
# 2    2020-01-03     1.9       6.1       0.1
# 3    2020-01-04    -1.0       4.7      -2.6
# 4    2020-01-05     1.0       4.7      -0.3
# ..          ...     ...       ...       ...
# 777  2024-03-01    -3.6       9.4      -7.4
# 778  2024-03-02    -5.1       9.7      -9.3
# 779  2024-03-03     1.9       5.4       0.4
# 780  2024-03-04     3.3       3.6       2.8
# 781  2024-03-05     5.2      19.1       1.4
#
# [782 rows x 4 columns]
