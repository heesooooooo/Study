# %% [markdown]
# # 데이터 시각화

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# 배열 생성하여 데이터 준비
x = np.arange(1,6)
np.random.seed(3)
y = np.random.randint(1,10,size=5)
print(x)
print(y)
# Out:
# [1 2 3 4 5]
# [9 4 9 9 1]

# %%
# 선 그래프 그리기
# plt.plot(x축 데이터, y축 데이터)
plt.plot(x,y)

# 주피터 노트북, colab 환경에서는 plot을 그릴 때 별도의 코드 없이 그래프가 출력된다
# vscode, pytorch 등에서는 plt.show()까지 작성
plt.show()

# %%
# 선 그리는 경우 x축 생략 가능
plt.plot(y)
plt.show()

# %% [markdown]
# # 선 그래프의 옵션
# <br>
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 선 그래프 스타일 변경
# marker - 포인트의 스타일 변경
# ms (marker size)
# mec (marker edge color)
# mew (marker edge width)
# mfc (marker face color)
plt.plot(x,y, ls =":", marker = '^', c='g', ms = 10, mec='k', mew=2, mfc='b')
plt.show()

# %%
# 하나의 출력문의 여러개 그래프 그리기
plt.plot(x,y, ls = '-', color='b' ,marker='D', ms=10, mec='c',mew=4, mfc='y')
plt.plot(x,y, ls = '--', color='m', lw=5)
plt.plot(x,y, ls = '-.')
plt.plot(x,y, ls = ':')
plt.show()

# 별도의 코드가 없으면 겹쳐서 출력

# %% [markdown]
# ### plt.subplot(row, col, index)
# -

# %%
# 하나의 출력문의 여러개 그래프 그리기
# plt.subplot()

plt.subplot(3,2,1)
plt.plot(x,y, ls = '-', color='b' ,marker='D', ms=10, mec='c',mew=4, mfc='y')

plt.subplot(3,2,2)
plt.plot(x,y, ls = '--', color='m', lw=5)

plt.subplot(3,2,3)
plt.plot(x,y, ls = '-.')

plt.subplot(3,2,4)
plt.plot(x,y, ls = ':')

plt.subplot(3,2,5)
plt.plot(x,y, ls = ':')

plt.subplot(3,2,6)
plt.plot(x,y, ls = ':')

plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 배열 생성하여 데이터 준비
test_x = np.arange(1,6)
np.random.seed(4)
test_y = np.random.randint(1,10,size=5)

plt.plot(test_x, test_y)
plt.show()

# %%
# 그래프 제목 - title
plt.title('hello, world!')
plt.plot(test_x, test_y)
plt.show()

# %%
# 격자 눈금 - gird
plt.grid()
plt.title('test')
plt.plot(test_x, test_y)
plt.show()

# %%
# 범례 - legend
test_x1 = np.arange(1,6)
np.random.seed(10)
test_y1 = np.random.randint(1,10,size=5)

plt.legend() # 아무런 코드 작성 없이 사용하면 아무것도 안 나옴

plt.plot(test_x, test_y)
plt.plot(test_x1, test_y1)

plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# 범례 - legend
test_x1 = np.arange(1,6)
np.random.seed(10)
test_y1 = np.random.randint(1,10,size=5)

plt.plot(test_x, test_y, label='test1')
plt.plot(test_x1, test_y1, label='test2')

# plt.plot 다음에 legend 작성하기
plt.legend() # 등장하게 하고 싶으면 plt.plot하는 구간에 label을 작성

plt.show()

# %%
#한글 폰트 깨질 경우
plt.rcParams['font.family'] = 'Malgun Gothic'

# %%
# xlabel, ylabel
plt.plot(test_x, test_y, label='test1')
plt.plot(test_x1, test_y1, label='test2')

plt.xlabel("x축")
plt.ylabel("y축", rotation = 0, loc = 'top') # rotation은 label 회전 숫자의 각도
# location은 label의 회전, 숫자의 의미는 각도
# loc top, bottom center 중 하나

plt.show()

# %%
# xlim, ylim - limit의 약자
# xlim(n, m) : n부터 m까지

plt.plot(test_x, test_y, label='test1')
plt.plot(test_x1, test_y1, label='test2')
plt.xlim(0,10)
plt.ylim(0,10)

plt.show()

# %%
# plt.figure(figsize = (x,y)) - 단위는 인치
plt.figure(figsize=(15,3))

plt.plot(test_x, test_y, label='test1')
plt.plot(test_x1, test_y1, label='test2')

plt.show()

# %%
# xticks, yticks - 눈금의 범위 조정

plt.plot(test_x, test_y, label='test1')
plt.plot(test_x1, test_y1, label='test2')

# list, 배열 형식 - list의 크기가 데이터의 개수와는 상관이 없다
plt.xticks([1,2,3,4,5,6,7])
plt.yticks([1,3,5,7,9])

plt.show()

# %% [markdown]
# ## 인구변동 데이터

# %%
data = pd.read_csv('data/장래_인구변동_KOSIS.csv', encoding = 'euc-kr', index_col = '인구변동요인별')
data
# Out:
#            2020   2030   2040   2050   2060   2070
# 인구변동요인별
# 인구(천명)    51836  51199  50193  47359  42617  37656
# 출생아수(천명)    275    305    286    236    181    196
# 사망자수(천명)    308    408    527    680    741    702

# %% [markdown]
# #### 연도별 출생아수, 사망자수를 데이터 시각화

# %%
# 출생아수 데이터 접근
data_y1 = data.iloc[1]  # [ : , :] 인데 모든 열이라 뒤에는 생략 가능 =[1, :]

# 사망자수 데이터 접근
data_y2 = data.iloc[2]
data_y2
# Out:
# 2020    308
# 2030    408
# 2040    527
# 2050    680
# 2060    741
# 2070    702
# Name: 사망자수(천명), dtype: int64

# %%
# 컬럼명을 뽑아 x축으로 설정
data_x = data.columns

# %%
plt.plot(data_x, data_y1, marker = '*', ms=10, label='출상아수(천명)')

plt.plot(data_x, data_y2, marker='o', ms=8, label='사망자수(천명)')

# title
plt.title('국가통계 요인별 장래 인구 동향')

# grid
plt.grid()

# legend - plot label 작성해주기!
plt.legend()

#plt.show()

# plt.savefig(경로+파일명, dpi(인치당 도트) - 숫자가 높을수록 고해상도
#               , bbox_inches='tight' - 빈칸 최소화)
plt.savefig('./kosis 요인별 장래 인구 동향.png', dpi=600, bbox_inches='tight')

# %% [markdown]
# ## 기상데이터

# %%
tdata = pd.read_csv('data/기상데이터.csv', encoding='euc-kr', skiprows=range(0,7))
tdata.head(2)
# Out:
#              날짜   지점  평균기온(℃)  최저기온(℃)  최고기온(℃)
# 0  \t2010-01-01  156     -3.6     -9.5      1.9
# 1  \t2010-01-02  156      1.6     -3.9      6.6

# %%
tdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5159 entries, 0 to 5158
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   날짜       5159 non-null   object
#  1   지점       5159 non-null   int64
#  2   평균기온(℃)  5159 non-null   float64
#  3   최저기온(℃)  5159 non-null   float64
#  4   최고기온(℃)  5159 non-null   float64
# dtypes: float64(3), int64(1), object(1)
# memory usage: 201.7+ KB

# %%
# 최저기온 시각화

# 최저기온 데이터 접근
t_y = tdata['최저기온(℃)']

# %%
plt.plot(t_y)
plt.show()

# %%
#마이너스 기호 사용 코드
plt.rcParams['axes.unicode_minus'] = False

# %%
# 마이너스 출력 코드

plt.plot(t_y)
plt.show()

# %%
# 데이터 정제의 필요성
# 데이터 파생변수 만들기

# 월일 이라는 파생변수
tdata['월일'] = tdata['날짜'].str[-5:] # 슬라이싱
tdata
# Out:
#                 날짜   지점  평균기온(℃)  최저기온(℃)  최고기온(℃)     월일
# 0     \t2010-01-01  156     -3.6     -9.5      1.9  01-01
# 1     \t2010-01-02  156      1.6     -3.9      6.6  01-02
# 2     \t2010-01-03  156      0.4     -1.8      3.5  01-03
# 3     \t2010-01-04  156      0.5     -1.8      5.7  01-04
# 4     \t2010-01-05  156     -3.0     -4.9      0.2  01-05
# ...            ...  ...      ...      ...      ...    ...
# 5154  \t2024-02-11  156      3.2     -1.2      9.1  02-11
# 5155  \t2024-02-12  156      5.8     -0.9     13.0  02-12
# 5156  \t2024-02-13  156     10.6      3.4     17.6  02-13
# 5157  \t2024-02-14  156     13.5     10.6     19.0  02-14
# 5158  \t2024-02-15  156      6.4      0.5     12.4  02-15
#
# [5159 rows x 6 columns]

# %%
# 본인 생일날짜 평균기온 연도별 그래프로 시각화

#1. 본인 생일날짜 불리언 인덱싱
tdata.query("월일 == '03-20'")

birthday_tdata = tdata.query("월일 == '03-20'")
birthday_tdata
# Out:
#                 날짜   지점  평균기온(℃)  최저기온(℃)  최고기온(℃)     월일
# 78    \t2010-03-20  156     13.3      5.9     20.7  03-20
# 443   \t2011-03-20  156      8.6      6.0     13.0  03-20
# 809   \t2012-03-20  156      4.4     -1.0     10.8  03-20
# 1174  \t2013-03-20  156      6.7     -1.1     13.5  03-20
# 1539  \t2014-03-20  156      7.2      4.7     12.0  03-20
# 1904  \t2015-03-20  156     13.6      8.5     22.1  03-20
# 2270  \t2016-03-20  156      9.2      3.5     17.7  03-20
# 2635  \t2017-03-20  156      8.7      5.7     13.1  03-20
# 3000  \t2018-03-20  156      7.7      1.3     13.6  03-20
# 3365  \t2019-03-20  156     12.5      7.7     16.7  03-20
# 3731  \t2020-03-20  156     10.6      5.4     16.9  03-20
# 4096  \t2021-03-20  156      9.7      6.8     13.3  03-20
# 4461  \t2022-03-20  156      5.2      3.0      8.8  03-20
# 4826  \t2023-03-20  156     11.3      3.3     19.3  03-20

# %%
#2. x,y 설정
y = birthday_tdata['평균기온(℃)']
x = range(2010,2024)

plt.plot(x,y)
plt.show()

# %% [markdown]
# # 히스토그램
# - 분포도 파악이 주 목적

# %%
# 데이터의 빈도를 막대 그래프 형태로 표시한 것
# 주사위를 100번 던져서 나오는 수들의 분포를 히스토그램으로 그려보기
np.random.seed(3)
a = np.random.randint(1,7, size = 100)
np.unique(a, return_counts=True) 

# his(데이터, bins = 가로의 구간 개수)
plt.hist(a, bins = 6)
plt.show()

# %%
a
# Out:
# array([3, 1, 2, 4, 1, 1, 1, 6, 6, 4, 3, 4, 2, 2, 3, 6, 1, 5, 5, 6, 1, 3,
#        2, 3, 3, 3, 5, 2, 4, 3, 6, 1, 2, 6, 3, 1, 4, 1, 4, 2, 4, 1, 6, 5,
#        2, 6, 5, 5, 1, 1, 2, 3, 5, 6, 1, 1, 6, 6, 2, 2, 2, 6, 6, 3, 4, 5,
#        5, 4, 4, 1, 1, 1, 1, 3, 3, 4, 1, 6, 6, 1, 6, 2, 5, 2, 5, 3, 3, 5,
#        5, 3, 1, 5, 1, 4, 3, 1, 5, 4, 2, 6])

# %%
# tdata 월 데이터 파생변수 만들기
tdata['월']=tdata['월일'].str[:2]
tdata
# Out:
#                 날짜   지점  평균기온(℃)  최저기온(℃)  최고기온(℃)     월일   월
# 0     \t2010-01-01  156     -3.6     -9.5      1.9  01-01  01
# 1     \t2010-01-02  156      1.6     -3.9      6.6  01-02  01
# 2     \t2010-01-03  156      0.4     -1.8      3.5  01-03  01
# 3     \t2010-01-04  156      0.5     -1.8      5.7  01-04  01
# 4     \t2010-01-05  156     -3.0     -4.9      0.2  01-05  01
# ...            ...  ...      ...      ...      ...    ...  ..
# 5154  \t2024-02-11  156      3.2     -1.2      9.1  02-11  02
# 5155  \t2024-02-12  156      5.8     -0.9     13.0  02-12  02
# 5156  \t2024-02-13  156     10.6      3.4     17.6  02-13  02
# 5157  \t2024-02-14  156     13.5     10.6     19.0  02-14  02
# 5158  \t2024-02-15  156      6.4      0.5     12.4  02-15  02
#
# [5159 rows x 7 columns]

# %%
# 2010~2024년 2월 데이터 최고기온을 히스토그램으로 시각화
#1. 2010~2024 2월 데이터 접근 -> 불리언 인덱싱
m2_tdata = tdata.query('월=="02"')
m2_tdata
# Out:
#                 날짜   지점  평균기온(℃)  최저기온(℃)  최고기온(℃)     월일   월
# 31    \t2010-02-01  156      3.6      0.5      7.9  02-01  02
# 32    \t2010-02-02  156     -0.6     -3.9      2.8  02-02  02
# 33    \t2010-02-03  156     -3.3     -5.4      0.4  02-03  02
# 34    \t2010-02-04  156     -1.4     -5.8      4.1  02-04  02
# 35    \t2010-02-05  156     -0.7     -4.3      4.4  02-05  02
# ...            ...  ...      ...      ...      ...    ...  ..
# 5154  \t2024-02-11  156      3.2     -1.2      9.1  02-11  02
# 5155  \t2024-02-12  156      5.8     -0.9     13.0  02-12  02
# 5156  \t2024-02-13  156     10.6      3.4     17.6  02-13  02
# 5157  \t2024-02-14  156     13.5     10.6     19.0  02-14  02
# 5158  \t2024-02-15  156      6.4      0.5     12.4  02-15  02
#
# [410 rows x 7 columns]

# %%
hist_tdata = m2_tdata['최고기온(℃)']

# %%
plt.hist(hist_tdata, bins=100)
plt.show()

# %%
# 히스토그램 꾸미기
# color - 색 바꾸기
# alpha - 투명도값 지정. 0~1사이 소수로 작성

# label - 지정가능
plt.hist(hist_tdata, bins=100, color='g', alpha=0.5, label='최고기온')

# 히스토그램도 겹치기 가능
plt.hist(m2_tdata['최저기온(℃)'], bins=100, color='b', alpha=0.5, label='최저기온')

plt.legend()
plt.title('2월 최고/최저기온')
plt.show()

# %% [markdown]
# # boxplot

# %%
# 1D 데이터 준비하여 박스 플롯 그려보기
np.random.seed(1)
tmp_data = np.random.randint(10,size = 10)
print(tmp_data)
tmp_data= np.append(tmp_data, 20)
print(tmp_data)
plt.boxplot(tmp_data, labels=['데이터명'])
plt.show()
# Out:
# [5 8 9 5 0 0 1 7 6 9]
# [ 5  8  9  5  0  0  1  7  6  9 20]

# %%
tmp_data
# Out:
# array([5, 8, 9, 5, 0, 0, 1, 7, 6, 9])

# %% [markdown]
# ### 1. 박스의 의미
#     - 데이터의 사분위 번위를 나타내는 것
#     - 2사분위와 3사분위의 데이터 표시
#
# ### 2. 수염의 의미
#     - 1사분위와 4사분위의 데이터
#
# ### 3. 박스 내 선 의미
#     - 중앙값
#
# ### 4. 점 -> 주로 점은 수염 바깥쪽에 존재
#     -이상치
#
# - 중앙값, 분위별 데이터 확인, 이상치 데이터 확인

# %%
m2_tdata['평균기온(℃)']
# Out:
# 31       3.6
# 32      -0.6
# 33      -3.3
# 34      -1.4
# 35      -0.7
#         ...
# 5154     3.2
# 5155     5.8
# 5156    10.6
# 5157    13.5
# 5158     6.4
# Name: 평균기온(℃), Length: 410, dtype: float64

# %%
m2_tdata[m2_tdata['평균기온(℃)']<-5]
# Out:
#                 날짜   지점  평균기온(℃)  최저기온(℃)  최고기온(℃)     월일   월
# 762   \t2012-02-02  156     -7.9     -9.7     -5.2  02-02  02
# 768   \t2012-02-08  156     -5.7     -9.3     -2.0  02-08  02
# 1134  \t2013-02-08  156     -6.3     -9.7     -1.4  02-08  02
# 2956  \t2018-02-04  156     -5.9     -8.3     -3.0  02-04  02
# 2957  \t2018-02-05  156     -5.6     -8.5     -1.7  02-05  02
# 2958  \t2018-02-06  156     -6.5     -9.8     -2.8  02-06  02

# %%
m2_tdata[m2_tdata['평균기온(℃)']>14]
# Out:
#                 날짜   지점  평균기온(℃)  최저기온(℃)  최고기온(℃)     월일   월
# 54    \t2010-02-24  156     14.5      5.9     20.6  02-24  02
# 55    \t2010-02-25  156     15.9     14.5     18.6  02-25  02
# 2234  \t2016-02-13  156     14.2      6.5     19.8  02-13  02

# %%
# plt.boxplot(데이터, labels=[])

# %%
plt.boxplot(m2_tdata['평균기온(℃)'], labels=['평균기온'])
plt.show()

# %% [markdown]
# # barplot

# %%
# 데이터 준비하여 막대 그래프 그려보기
np.random.seed(6)
bar_x = np.arange(1,4)
bar_y = np.random.randint(50,100,size=3)

# plt.bar(x,y)
plt.bar(bar_x,bar_y)
plt.show()

# %%
# barplot 꾸미기
# https://matplotlib.org/stable/gallery/color/named_colors.html#base-colors  doc제공 코드
import math
from matplotlib.patches import Rectangle
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors


def plot_colortable(colors, *, ncols=4, sort_colors=True):

    cell_width = 212
    cell_height = 22
    swatch_width = 48
    margin = 12

    # Sort colors by hue, saturation, value and name.
    if sort_colors is True:
        names = sorted(
            colors, key=lambda c: tuple(mcolors.rgb_to_hsv(mcolors.to_rgb(c))))
    else:
        names = list(colors)

    n = len(names)
    nrows = math.ceil(n / ncols)

    width = cell_width * 4 + 2 * margin
    height = cell_height * nrows + 2 * margin
    dpi = 72

    fig, ax = plt.subplots(figsize=(width / dpi, height / dpi), dpi=dpi)
    fig.subplots_adjust(margin/width, margin/height,
                        (width-margin)/width, (height-margin)/height)
    ax.set_xlim(0, cell_width * 4)
    ax.set_ylim(cell_height * (nrows-0.5), -cell_height/2.)
    ax.yaxis.set_visible(False)
    ax.xaxis.set_visible(False)
    ax.set_axis_off()

    for i, name in enumerate(names):
        row = i % nrows
        col = i // nrows
        y = row * cell_height

        swatch_start_x = cell_width * col
        text_pos_x = cell_width * col + swatch_width + 7

        ax.text(text_pos_x, y, name, fontsize=14,
                horizontalalignment='left',
                verticalalignment='center')

        ax.add_patch(
            Rectangle(xy=(swatch_start_x, y-9), width=swatch_width,
                      height=18, facecolor=colors[name], edgecolor='0.7')
        )

    return fig

# %%
plot_colortable(mcolors.CSS4_COLORS)
plt.show()

# %%
# barplot 꾸미기
# color 지정
plt.bar(bar_x, bar_y, color = 'lightsteelblue')
plt.show()

# %%
# bar별 color 별도 적용
# color = []
plt.bar(bar_x, bar_y, color = ['lightsteelblue','lightpink','lightgreen'])
plt.show()

# %%
bar_x
# Out:
# array([1, 2, 3])

# %%
bar_y
# Out:
# array([60, 59, 85])

# %%
# bar에 데이터 값 작성
plt.bar(bar_x, bar_y, color = ['lightsteelblue','lightpink','lightgreen'])

# plt.text(x,y,'str', fontdict={'color' : '', 'size':00 })
# plt.text(1, 60, '60', fontdict={'color' : 'black', 'size':10 })
# plt.text(2, 59, '59', fontdict={'color' : 'black', 'size':10 })
# plt.text(3, 85, '85', fontdict={'color' : 'black', 'size':10 })

# text(ha=, va= )
# ha = horizontal alignment
# va = vertical alignment

# ha = center, right, left
# va = top, bottom, center, baseline, center_baseline


for i in range(len(bar_x)):
    plt.text(bar_x[i], bar_y[i], bar_y[i], fontdict={'color' : 'black', 'size':10 }
            , ha='center', va='bottom')
# 텍스트 기준으로... 중앙선의 위치를 지정.. 

plt.show()

# %%
economic = pd.read_csv('data/시도_성별_경제활동인구_총괄_KOSIS_2022.csv', encoding = 'euc-kr')
economic.head()
# Out:
#   행정구역(시도)  성별  15세이상인구 (천명)  경제활동인구 (천명)  취업자 (천명)  실업자 (천명)  비경제활동인구 (천명)  \
# 0    서울특별시  남자          4007         2849      2760        89          1158
# 1    서울특별시  여자          4440         2418      2347        72          2022
# 2    부산광역시  남자          1406          973       946        27           433
# 3    부산광역시  여자          1528          768       745        23           760
# 4    대구광역시  남자          1001          708       691        17           294
#
#    경제활동참가율(％)  고용률(%)  실업률(%)
# 0        71.1    68.9     3.1
# 1        54.5     NaN     3.0
# 2        69.2    67.3     2.7
# 3        50.3    48.8     3.0
# 4        70.6    69.0     2.3

# %%
economic.info()
# 고용률, 실업률 데이터 몇개 없음
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   행정구역(시도)      34 non-null     object
#  1   성별            34 non-null     object
#  2   15세이상인구 (천명)  34 non-null     int64
#  3   경제활동인구 (천명)   34 non-null     int64
#  4   취업자 (천명)      34 non-null     int64
#  5   실업자 (천명)      34 non-null     int64
#  6   비경제활동인구 (천명)  34 non-null     int64
#  7   경제활동참가율(％)    34 non-null     float64
#  8   고용률(%)        24 non-null     float64
#  9   실업률(%)        28 non-null     float64
# dtypes: float64(3), int64(5), object(2)
# memory usage: 2.8+ KB

# %%
economic['고용률(%)']

# 고용률 = 취업자 / 15세 이상 인구
# 계산해서 수정해버리자
economic['고용률(%)'] = economic['취업자 (천명)'] / economic['15세이상인구 (천명)'] *100
economic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   행정구역(시도)      34 non-null     object
#  1   성별            34 non-null     object
#  2   15세이상인구 (천명)  34 non-null     int64
#  3   경제활동인구 (천명)   34 non-null     int64
#  4   취업자 (천명)      34 non-null     int64
#  5   실업자 (천명)      34 non-null     int64
#  6   비경제활동인구 (천명)  34 non-null     int64
#  7   경제활동참가율(％)    34 non-null     float64
#  8   고용률(%)        34 non-null     float64
#  9   실업률(%)        28 non-null     float64
# dtypes: float64(3), int64(5), object(2)
# memory usage: 2.8+ KB

# %%
state_emp = economic[['행정구역(시도)','고용률(%)']].groupby('행정구역(시도)',as_index = False).mean()

state_emp.head()
# Out:
#   행정구역(시도)     고용률(%)
# 0      강원도  63.980543
# 1      경기도  64.251431
# 2     경상남도  61.391891
# 3     경상북도  64.097240
# 4    광주광역시  59.787050

# %%
# 5) 시도별 고용률 평균 막대 그래프로 시각화하고 고용률이 가장 높은 지역 확인
# Vertical Bar (수직 막대그래프)
plt.figure(figsize =(8,4))
plt.bar(state_emp['행정구역(시도)'],state_emp['고용률(%)'])
plt.xticks(rotation = 45)
plt.title('시도별 고용률 평균 시각화')
plt.xlabel('행정구역(시도)')
plt.ylabel('고용률(%)', rotation=0)
# ylim 크기 55~80 조절해서 확인
plt.ylim(55,80)
plt.show()
